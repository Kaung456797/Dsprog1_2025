# %%
# Web スクレイピングに最低限必要なライブラリをインポーと
import requests
from bs4 import BeaytifulSoup

# %%
print(f"レスポンス：{res}") #レスポンスオブジェクトを表示
print(f"レスポンスの型：{type(res)}") #れスポンスオブジェクトの型を表示
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(f"レスポンス：{res}") #レスポンスオブジェクトを表示
#       2 print(f"レスポンスの型：{type(res)}") #れスポンスオブジェクトの型を表示
#
# NameError: name 'res' is not defined

# %%
#レスポンス
print(f"レスポンスヘッダー：{res.headers}") #レスポンスヘッダーを表示
print(f"レスポンスディ":{res.text}) #レスポンスディを表示
# Out:
#   Cell In[9], line 3
#     print(f"レスポンスディ":{res.text}) #レスポンスディを表示
#                     ^
# SyntaxError: invalid syntax

# %%
#別のURLにアクセスしてみる
#url = "https://ja.wikipedia.org/wiki/%E6%AD%A6%E8%94%B5%E9%87%8E%E5%A4%A7%E5%AD%A6"
url='https://www.musashino-u.ac.jp/search.html'
params={
    'qurecy': 'データサイエンス'
}
res = requests.get(url,headers=headers,params=params)
res.encoding = res.apparent_encoding #レスポンスのエンコーディングを設定
print(f"ステータスコード：{res.stsats_code}") #ステータスコードを表示
print(f"レスポンスボディ:{res.text}") #レスポンスボディを表示
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 7
#       3 url='https://www.musashino-u.ac.jp/search.html'
#       4 params={
#       5     'qurecy': 'データサイエンス'
#       6 }
# ----> 7 res = requests.get(url,headers=headers,params=params)
#       8 res.encoding = res.apparent_encoding #レスポンスのエンコーディングを設定
#       9 print(f"ステータスコード：{res.stsats_code}") #ステータスコードを表示
#
# NameError: name 'requests' is not defined

# %%
# ソースコード全体から<div>タグを抽出
soup_div = soup.div
# print(f"<div>タグ：{soup_div}")  #最後に見つかった<div>タグを表示
# print(f"<div>タグの型：{type(soup_div)}")  #<div>タグオブジェクトの型を表示

# soup_div_div= soup_div_div
# print(f"<div>タグの中の<div>タグ：{soup_div_div}")  #最後に見つかった<div>タグを表示
# print(f"<div>タグの中の<div>タグの型：{type(s_div_div)}")  #<div>タグオブジェクトの型を表示
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # ソースコード全体から<div>タグを抽出
# ----> 2 soup_div = soup.div
#       3 # print(f"<div>タグ：{soup_div}")  #最後に見つかった<div>タグを表示
#       4 # print(f"<div>タグの型：{type(soup_div)}")  #<div>タグオブジェクトの型を表示
#       5
#       6 # soup_div_div= soup_div_div
#       7 # print(f"<div>タグの中の<div>タグ：{soup_div_div}")  #最後に見つかった<div>タグを表示
#       8 # print(f"<div>タグの中の<div>タグの型：{type(s_div_div)}")  #<div>タグオブジェクトの型を表示
#
# NameError: name 'soup' is not defined
