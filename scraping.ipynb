# %%
#指定したタグが使われている要素のうち、最初に見つかった要素を取得する
h2 = soup.find('h2')
print(f"{h2}")

# %%
h2_all = soup.find_all('h2')
print(f"<h2>タグのリスト: {h2_all}")　＃見つかった<h2>タグのリストを表示
print(f"リスクの型：{type(h2_all)}")　＃<h2>リストの型を表示

# %%
h2_all = soup.find_all('h2')
#print

# %%
a_list = soup.find_all('a')

# %%
#id属性やclass属性など、任意の属性で検索することも可能である.
#例えば、id属性が"main-top"の要素を取得するには、次のようにする.
tag_id_list = soup.find_all(id='top')
for tag in tag_id_list:
    print(f"{tag}") #id属性が"top"のタグを表示
    
    
tag_class_list = soup.find_all(class_='p_notices, limit=5')
for tag in tag_class_list:
    print(f"{tag}") #class属性が"p_notices"のタグを表示
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 #id属性やclass属性など、任意の属性で検索することも可能である.
#       2 #例えば、id属性が"main-top"の要素を取得するには、次のようにする.
# ----> 3 tag_id_list = soup.find_all(id='top')
#       4 for tag in tag_id_list:
#       5     print(f"{tag}") #id属性が"top"のタグを表示
#
# NameError: name 'soup' is not defined

# %%
## CSSセレクタを使った検査

# %%
# id属性を指定（#　＋　検査ID名）
top_tags = soup.select('#top')
for tag in top_tags:
    print(f"{tag}")  # id属性が"top"のタグを表示
    
# class属性を指定（ ）
class_tags = soup.select('.p_notices')
for tag in class_tags:
    print(f"{tag}")  # class属性が"p_notices"のタグを表示
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # id属性を指定（#　＋　検査ID名）
# ----> 2 top_tags = soup.select('#top')
#       3 for tag in top_tags:
#       4     print(f"{tag}")  # id属性が"top"のタグを表示
#
# NameError: name 'soup' is not defined

# %%
import time

# %%
for i in range(5):
    time.sleep(1) #プログラムを1秒間停止
    print(f"アクセス回数：{i+1}")
